# %%
from __future__ import division, print_function
import sys
import os
# %pylab notebook
import pandas as pd
import numpy as np
import seaborn
import random
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.DataFrame()
df['stat_dist'] = np.random.random(1000)

# random mapping
male_idx = random.sample(range(1000), k=500)
df['gender'] = 'female'
df['gender'].loc[male_idx] = 'male'
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.head()
# Out:
#    stat_dist  gender
# 0   0.910980    male
# 1   0.403633  female
# 2   0.781476  female
# 3   0.441304  female
# 4   0.244810    male

# %%
# ax = seaborn.swarmplot(x='gender', y='stat_dist', data=df)
ax = seaborn.violinplot(x='gender', y='stat_dist', data=df, cut=0,rot=90, alpha=0.4)
# plt.ylim((0,df.max().max()))
# Out:
# <img src="data:image/png;base64,...">
